# %% [markdown]
# ##### 导入库

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets

# %% [markdown]
# ##### 选择数据

# %%
n='★阴性整合.csv'
n="alln++.csv"
p='★阳性整合.csv'
# p='纯冰毒-重复.csv'
# p='纯海洛因-重复.csv'
# p='混吸.csv'

# %% [markdown]
# ##### 读取数据

# %%
path='E:\\desktop\\data\\'
n_fea = pd.read_csv(path+'fea\\[特征]'+n,encoding="gbk")
p_fea = pd.read_csv(path+'fea\\[特征]'+p,encoding="gbk")

n_fea["tag"]=[0 for i in range(len(n_fea))]
p_fea["tag"]=[1 for i in range(len(p_fea))]

np_fea=pd.concat([n_fea,p_fea],axis=0)
np_fea.dropna(axis=1, how='any', inplace=True)
fea_list=list(set(np_fea.columns)-{"name","tag"})


X=np_fea[fea_list]
Y=np_fea['tag']
print(len(n_fea),len(p_fea))
np_fea

X
# Out:
# 382 382
#      value__cwt_coefficients__coeff_10__w_10__widths_(2, 5, 10, 20)  \
# 0                                            63.683157
# 1                                            55.391543
# 2                                            60.838825
# 3                                            42.141199
# 4                                            61.136527
# ..                                                 ...
# 377                                          47.223834
# 378                                          40.832677
# 379                                          58.638202
# 380                                          49.486419
# 381                                          56.085707
#
#      value__cwt_coefficients__coeff_8__w_10__widths_(2, 5, 10, 20)  \
# 0                                            60.224417
# 1                                            52.200110
# 2                                            57.149882
# ...

# %%
trainedforest = RandomForestClassifier(n_estimators=700).fit(X,Y)

import_dict=dict(zip(fea_list,list(trainedforest.feature_importances_)))
import_dict = dict(sorted(import_dict.items(), key=lambda x: x[1],reverse=True))#

import_dict
# Out:
# {'value__fft_coefficient__attr_"imag"__coeff_3': 0.022636387097630783,
#  'value__fft_coefficient__attr_"angle"__coeff_3': 0.015847056743083923,
#  'value__fft_coefficient__attr_"real"__coeff_2': 0.015781533948278356,
#  'value__agg_linear_trend__attr_"stderr"__chunk_len_50__f_agg_"min"': 0.01543319227702828,
#  'value__agg_linear_trend__attr_"stderr"__chunk_len_50__f_agg_"mean"': 0.012395605343954692,
#  'value__agg_linear_trend__attr_"rvalue"__chunk_len_50__f_agg_"min"': 0.012242112639617131,
#  'value__spkt_welch_density__coeff_2': 0.01219778539773905,
#  'value__energy_ratio_by_chunks__num_segments_10__segment_focus_4': 0.011307935947992807,
#  'value__fft_coefficient__attr_"angle"__coeff_2': 0.010613340331176155,
#  'value__standard_deviation': 0.00976812705628499,
#  'value__fft_coefficient__attr_"abs"__coeff_1': 0.008443779459152258,
#  'value__variance': 0.008421770311112166,
#  'value__agg_linear_trend__attr_"stderr"__chunk_len_10__f_agg_"mean"': 0.00839703072654492,
# ...

# %%
# selector = SelectFromModel(estimator=RandomForestClassifier()).fit(X, Y)
# selector.estimator_.coef_

# selector.transform(X)
# print(len(selector.get_support()))
# print(selector.threshold_)

# print(len(fea_list))
# selector.get_feature_names_out()
